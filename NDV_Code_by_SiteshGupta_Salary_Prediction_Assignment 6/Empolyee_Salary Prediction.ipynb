# %%
print("Hello,Sitesh Gupta")
# Out:
# Hello,Sitesh Gupta

# %% [markdown]
# 1.
#
#
# : Predict a person’s salary based on years of experience.
#
# : YearsExperience
#
# : Salary
#
# : Kaggle Dataset
# https://www.kaggle.com/datasets/karthickveerakumar/salary-data-simple-linear-regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
Salary_data = pd.read_csv('Salary_Data.csv')

# %%
df = pd.DataFrame(Salary_data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.tail()
# Out:
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
print(Salary_data.columns)
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
X = df[['YearsExperience']]
y = df['Salary']

# %%
plt.scatter(x='YearsExperience', y='Salary', data=Salary_data, color='blue')
plt.title('Years of Experience vs Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred =model.predict(X)

# %%
result = pd.DataFrame({'Actual Values': y, 'Predicted Values': y_pred})
print(result)
# Out:
#     Actual Values  Predicted Values
# 0         39343.0      36187.158752
# 1         46205.0      38077.151217
# 2         37731.0      39967.143681
# 3         43525.0      44692.124842
# 4         39891.0      46582.117306
# 5         56642.0      53197.090931
# 6         60150.0      54142.087163
# 7         54445.0      56032.079627
# 8         64445.0      56032.079627
# 9         57189.0      60757.060788
# 10        63218.0      62647.053252
# 11        55794.0      63592.049484
# 12        56957.0      63592.049484
# 13        57081.0      64537.045717
# 14        61111.0      68317.030645
# 15        67938.0      72097.015574
# 16        66029.0      73987.008038
# 17        83088.0      75877.000502
# 18        81363.0      81546.977895
# 19        93940.0      82491.974127
# 20        91738.0      90051.943985
# 21        98273.0      92886.932681
# 22       101302.0     100446.902538
# 23       113812.0     103281.891235
# 24       109431.0     108006.872395
# ...

# %%
r2 = r2_score(y, y_pred)
print(f"R2 Score: {r2:.2f}")
# Out:
# R2 Score: 0.96

# %%
print(f"Slope(m): {model.coef_[0]}")
print(f"Intercept(c): {model.intercept_}")
# Out:
# Slope(m): 9449.962321455074
# Intercept(c): 25792.20019866871

# %%
plt.scatter(x='YearsExperience', y='Salary', data=Salary_data, label='Data')
plt.plot(X, model.predict(X), color='red', label='Regression Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Linear Regression Fit')
plt.legend()
plt.show()
